# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.describe()
# Out:
#              cgpa          iq   placement
# count  100.000000  100.000000  100.000000
# mean     5.991000  123.580000    0.500000
# std      1.143634   39.944198    0.502519
# min      3.300000   37.000000    0.000000
# 25%      5.075000  101.500000    0.000000
# 50%      6.000000  127.500000    0.500000
# 75%      6.900000  149.000000    1.000000
# max      8.500000  233.000000    1.000000

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
 import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1:]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
#     placement
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ..        ...
# 95          0
# 96          0
# 97          1
# 98          1
# 99          1
#
# [100 rows x 1 columns]

# %%
X.shape
Y.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,Y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 18   4.0  100.0
# 17   3.3  183.0
# 81   5.4  107.0
# 39   4.6  146.0
# 5    7.1   48.0
# ..   ...    ...
# 31   3.9  109.0
# 76   4.9  155.0
# 32   7.0  139.0
# 22   4.9  120.0
# 87   5.7  132.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
#     placement
# 18          0
# 17          0
# 81          0
# 39          0
# 5           1
# ..        ...
# 31          0
# 76          0
# 32          1
# 22          0
# 87          1
#
# [90 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
x_train = scalar.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.74042055, -0.65246711],
#        [-2.35989227,  1.47774675],
#        [-0.50147711, -0.47281052],
#        [-1.20944479,  0.52813334],
#        [ 1.00295422, -1.98705892],
#        [ 0.91445826,  1.88839038],
#        [-0.14749327,  1.04143788],
#        [ 0.02949865,  0.60512902],
#        [ 0.29498653,  0.06615925],
#        [ 0.11799461,  0.16882016],
#        [-0.76696499, -1.52508483],
#        [ 0.73746634, -0.06216688],
#        [ 1.44543402, -0.93478461],
#        [-0.76696499,  1.29809016],
#        [ 0.56047441, -0.13916257],
#        [ 1.17994614, -0.24182347],
#        [ 0.29498653,  0.04049403],
#        [ 0.02949865, -0.60113665],
#        [ 0.20649057, -0.31881916],
#        [-0.85546095, -0.19049302],
#        [ 0.73746634, -0.34448438],
#        [-0.94395691,  1.8113947 ],
#        [ 0.8259623 , -0.75512802],
#        [-0.67846903, -0.90911938],
#        [ 1.2684421 ,  0.16882016],
#        [ 0.8259623 ,  0.34847675],
#        [-0.23598923,  1.11843357],
#        [ 0.91445826, -1.57641529],
#        [ 2.24189766, -0.13916257],
#        [-0.50147711,  0.34847675],
#        [ 1.88791382,  0.60512902],
#        [ 0.47197845, -2.26937642],
#        [ 1.35693806,  0.83611607],
#        [-1.12094883, -1.88439801],
#        [ 0.11799461, -0.57547143],
#        [ 2.06490574,  1.09276834],
#        [ 0.02949865, -0.03650166],
#        [-0.23598923,  0.45113766],
#        [-0.14749327,  0.42547243],
#        [ 1.88791382,  1.04143788],
#        [ 0.47197845,  0.11748971],
#        [-0.50147711, -0.29315393],
#        [-0.85546095, -0.88345415],
#        [-0.94395691, -1.65341097],
#        [-0.58997307, -0.29315393],
#        [ 0.11799461,  0.78478561],
#        [-0.50147711,  0.24581584],
#        [-0.94395691,  0.65645948],
#        [-0.67846903, -0.39581484],
#        [ 0.8259623 ,  0.32281152],
#        [ 1.17994614,  0.2971463 ],
#        [-0.76696499,  0.06615925],
#        [-0.05899731, -0.49847575],
#        [ 1.44543402,  0.06615925],
#        [-0.94395691,  0.22015062],
#        [-1.38643671, -2.14105028],
#        [ 0.73746634,  0.39980721],
#        [-0.23598923,  0.37414198],
#        [-1.12094883, -0.98611506],
#        [ 0.64897038,  0.73345516],
#        [-1.03245287,  1.11843357],
#        [ 1.17994614, -1.01178029],
#        [-2.18290035,  2.7610081 ],
#        [ 0.91445826,  1.27242493],
#        [ 0.47197845,  0.88744652],
#        [-1.03245287,  0.39980721],
#        [-1.47493267,  1.91405561],
#        [ 0.56047441,  0.32281152],
#        [-0.67846903,  2.53002106],
#        [-1.38643671,  0.60512902],
#        [ 0.38348249,  0.39980721],
#        [ 1.00295422,  0.65645948],
#        [-1.03245287, -0.34448438],
#        [ 0.38348249, -0.24182347],
#        [ 1.35693806,  0.11748971],
#        [ 0.02949865, -2.0640546 ],
#        [ 1.62242594, -0.29315393],
#        [ 0.11799461, -1.55075006],
#        [ 0.29498653, -0.57547143],
#        [-0.67846903,  0.16882016],
#        [ 1.17994614, -1.93572847],
#        [-1.12094883, -0.11349734],
#        [-0.85546095, -1.60208051],
#        [ 0.47197845, -0.90911938],
#        [-0.58997307, -0.11349734],
#        [-1.82891651, -0.42148006],
#        [-0.94395691,  0.75912039],
#        [ 0.91445826,  0.34847675],
#        [-0.94395691, -0.13916257],
#        [-0.23598923,  0.16882016]])

# %%
x_test = scalar.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-0.85272308,  1.26328319],
#        [-0.09287083, -0.60824746],
#        [-0.17729886, -0.95915946],
#        [ 0.66698142,  0.11697067],
#        [ 1.08912155, -1.07613012],
#        [ 0.41369733,  1.75455998],
#        [-1.86585941, -0.74861226],
#        [ 1.51126169, -0.65503573],
#        [-1.19043519,  1.31007145],
#        [ 0.49812536, -0.39770026]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
y_train = y_train.squeeze()
y_train
# Out:
# 18    0
# 17    0
# 81    0
# 39    0
# 5     1
#      ..
# 31    0
# 76    0
# 32    1
# 22    0
# 87    1
# Name: placement, Length: 90, dtype: int64

# %%
plot_decision_regions(x_train, y_train.to_numpy(), clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pk1','wb'))
